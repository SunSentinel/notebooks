# %% [markdown]
# # Rapidly intensifying hurricanes - Analysis

# %%
from datetime import datetime, timedelta

import pandas as pd
import numpy as np

import matplotlib
matplotlib.use('agg')
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ## 1. Load in the calculated data

# %%
all_storms_df = pd.read_csv('intensified_storms.csv')
all_storms_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 351 entries, 0 to 350
# Data columns (total 6 columns):
# Unnamed: 0         351 non-null int64
# Serial_Num         351 non-null object
# Season             351 non-null int64
# Name               351 non-null object
# Sub_basin          351 non-null object
# rapid_increases    351 non-null int64
# dtypes: int64(3), object(3)
# memory usage: 16.5+ KB

# %%
by_year = all_storms_df.groupby("Season").size().reset_index()

# %%
by_year.set_index("Season").plot.bar(figsize=(20, 10))

# %% [markdown]
# ### Look at storms that go into the Gulf of Mexico

# %%
gulf_storms = all_storms_df[all_storms_df["Sub_basin"] == "GM"]
gulf_storms
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, Serial_Num, Season, Name, Sub_basin, rapid_increases]
# Index: []
